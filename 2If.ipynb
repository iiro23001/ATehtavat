# %%
#1
Number1 = 3
Number2 = 3

if Number1 == Number2:
    print("Numerot yhtä suuria")
else:
    print("Numerot ei yhtä suuria")
if Number1 < Number2:
    print("Numero2 suurempi")
else:
    print("Numero1 suurempi")
if Number1 <= Number2:
    print("Numero2 suurempi tai yhtä suuri")
else:
    print("Numero1 suurempi")
if Number1 != Number2:
    print("Numerot ei yhtä suuria")
else:
    print("Numerot yhtä suuria")
#2
Numberb1 = 50
Numberb2 = 6
Numberb3 = 6

if Numberb1 == Numberb2 == Numberb3:
    print ("Numerot yhtä suuria")
else:
    print("Numerot ei yhtä suuria")
if Numberb1 == Numberb2 or Numberb2 == Numberb3:
    print("Kaksi numeroista on yhtä suuria")
else:
    print("Numerot 1,2 tai 2,3 ei ole yhtä suuria")
if Numberb1 > Numberb2 and Numberb1 > Numberb3:
    print("Numero1 on suurin")
else:
    print("Numero1 ei ole suurempi kuin Nro2, Nro3")
if Numberb1 > Numberb2:
    print("Numero1 on suurempi kuin Nro2")
elif Numberb2 > Numberb3:
    print("Numero1 on suurempi kuin Nro3")
else:
    print("Kummatkaan ei ole yhtä suuria")
if Numberb1 == Numberb2:
    print("Nro1 ja 2 ovat yhtä suuria")
elif Numberb1 == Numberb3:
    print("Nro1 ja 3 ovat yhtä suuria")
else:
    print("Mikään numeroista ei ole yhtä suuri")

#3
mystring1 = "Pekka"
mystring2 = "Joni"
mystring3 = "Pekka"
print ("Testi:", mystring1)
if mystring1 == mystring2:
    print("Nimet ovat samat")
else:
    print("Eri nimet")
if mystring2 != mystring3:
    print("Eri nimet")
else:
    print("Nimet ovat samat")
if mystring1 == mystring2:
    print("Nimet ovat samat")
elif mystring1 == mystring3:
    print("Nimet ovat samat")
else:
    print("Eri nimet")
# Out:
# Numerot yhtä suuria
# Numero1 suurempi
# Numero2 suurempi tai yhtä suuri
# Numerot yhtä suuria
# Numerot ei yhtä suuria
# Kaksi numeroista on yhtä suuria
# Numero1 on suurin
# Numero1 on suurempi kuin Nro2
# Mikään numeroista ei ole yhtä suuri
# Testi: Pekka
# Eri nimet
# Eri nimet
# Nimet ovat samat
